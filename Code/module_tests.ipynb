# %%
import seaborn as sns
from common.genomeTools import GenomeData, ComparisonEngine
from common.preprocessing import RandomSlice
# %matplotlib notebook

# %%
genomedata = GenomeData()
# Out:
# Retrieving file length...

# %%
window1000 = RandomSlice(slice_size = 1000)

# %%
CE = ComparisonEngine(genomedata, preprocessing=window1000)
# Out:
# data extr. (Data/22hap0.gz): 100%|██████████| 1092/1092 [04:50<00:00,  3.76it/s]
# 	done.

# %%
CE.apply()
# Out:
# pairwise metric: 100%|██████████| 1091/1091 [00:15<00:00, 68.52it/s]
# array([[ 1.        ,  0.9379845 ,  0.91570881, ...,  0.95982362,
#          0.93986421,  0.85013876],
#        [ 0.9379845 ,  1.        ,  0.96078431, ...,  0.90566937,
#          0.9047619 ,  0.84501845],
#        [ 0.91570881,  0.96078431,  1.        , ...,  0.90930788,
#          0.90294957,  0.85356812],
#        ...,
#        [ 0.95982362,  0.90566937,  0.90930788, ...,  1.        ,
#          0.92771084,  0.85960019],
#        [ 0.93986421,  0.9047619 ,  0.90294957, ...,  0.92771084,
#          1.        ,  0.86567164],
#        [ 0.85013876,  0.84501845,  0.85356812, ...,  0.85960019,
#          0.86567164,  1.        ]])

# %%
sns.heatmap(CE.apply())
# Out:
# <img src="data:image/png;base64,..." width="640">
